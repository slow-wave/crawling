# %% [markdown]
# ## category code 정리
# 원피스
# - 미니 원피스 : 020006

# %% [markdown]
# ### column
# - category
# - sub_category
# - item_id
# - img_url

# %%
import requests
from bs4 import BeautifulSoup

# %%
#원피스 > 미니 원피스 크롤링
req = requests.get('https://search.musinsa.com/category/020006?device=&d_cat_cd=020006&brand=&rate=&page_kind=search&list_kind=small&sort=pop&sub_sort=&page=1&display_cnt=90&sale_goods=&ex_soldout=&color=&price1=&price2=&exclusive_yn=&size=&tags=&sale_campaign_yn=&timesale_yn=&q=')
raw = req.text

html = BeautifulSoup(raw, 'html.parser')

# %%
html.select('label.is_goods')
# Out:
# [<label class="is_goods"> 상품 수 : 2,096개</label>]

# %%
html.select('span.totalPagingNum')
# Out:
# [<span class="totalPagingNum">24</span>,
#  <span class="totalPagingNum">24</span>]

# %%
html.select('span.currentPagingNum')
# Out:
# [<span class="currentPagingNum">1</span>,
#  <span class="currentPagingNum">1</span>]

# %%
infos_1 = html.select('ul.snap-article-list')
print(infos_1)
# Out:
# [<ul class="snap-article-list boxed-article-list article-list center list goods_small_media8" id="searchList">
# <li class="li_box" data-no="1854239">
# <div class="icon_new">NEW</div>
# <div class="icon_group">
# <ul>
# <li class="icon_woman sight_out" title="여성">여성</li>
# </ul>
# </div>
# <div class="li_inner">
# <div class="list_img">
# <a class="img-block" href="https://store.musinsa.com/app/goods/1854239" name="goods_link" title="엠마 트위드 체크 드레스_블랙">
# <img alt="엠마 트위드 체크 드레스_블랙" class="lazyload lazy" data-original="https://image.msscdn.net/images/goods_img/20210319/1854239/1854239_1_125.jpg" src="//image.msscdn.net/images/no_image_125.png">
# </img></a>
# </div>
# <div class="article_info">
# <p class="item_title"><a href="https://store.musinsa.com/app/brand/goods_list/judemccall">주드맥콜</a></p>
# <p class="list_info">
# <a href="https://store.musinsa.com/app/goods/1854239" name="goods_link" title="엠마 트위드 체크 드레스_블랙">
#
#
#                                     엠마 트위드 체크 드레스_블랙
# ...

# %%
infos_1[0].li['data-no']
# Out:
# '1854239'

# %%
infos_1[0].img['data-original']
# Out:
# 'https://image.msscdn.net/images/goods_img/20210319/1854239/1854239_1_125.jpg'
